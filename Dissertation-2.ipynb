# %% [markdown]
# # Imports and configurations

# %% [markdown]
# Import packages

# %%
import yfinance as yf
import pandas as pd 
import numpy as np
import os
import pathlib
import glob
import urllib
import zipfile
import datetime as dt 
from tqdm import tqdm
import scipy
from sklearn.linear_model import LinearRegression #prediction
import pandas_datareader as web
from dateutil.relativedelta import *
from pandas.tseries.offsets import *
import statsmodels.api as sm
import matplotlib

idx=pd.IndexSlice

# %% [markdown]
# Set notebooks configurations

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 80%; }
    div#maintoolbar-container { width: 60%; }
</style>
"""))

pd.set_option('display.max_columns', 60)
pd.set_option('display.max_rows', 350)
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 80%; }
#     div#maintoolbar-container { width: 60%; }
# </style>

# %% [markdown]
# Set paths

# %%
dissertation_folder=os.getcwd()+os.sep
dissertation_folder
# Out:
# '/Users/jean-baptistecrepelle/Desktop/Learning/Andrea/Dissertation/'

# %%
if not os.path.exists('data'):
    os.makedirs('data')

# %%
data_folder=os.path.join(os.getcwd(),'data')+os.sep
data_folder
# Out:
# '/Users/jean-baptistecrepelle/Desktop/Learning/Andrea/Dissertation/data/'

# %% [markdown]
# # Data downloading

# %% [markdown]
# ## FF5

# %% [markdown]
# Descriptions of Fama French 5 factors (2x3) can be found on Kenneth French's website.<br>
# http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html

# %% [markdown]
# Read the original FF5 data

# %%
ff_url = "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_daily_CSV.zip"
urllib.request.urlretrieve(ff_url,'F-F_Research_Data_Factors_daily_CSV.zip')
# Out:
# ('F-F_Research_Data_Factors_daily_CSV.zip',
#  <http.client.HTTPMessage at 0x11e4062e8>)

# %%
zip_file = zipfile.ZipFile('F-F_Research_Data_Factors_daily_CSV.zip', 'r')
zip_file.extractall()
zip_file.close()

# %%
ff_factors_original = pd.read_csv('F-F_Research_Data_5_Factors_2x3_daily.csv', skiprows = 3)
ff_factors_original
# Out:
#        Unnamed: 0  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0        19630701   -0.67  0.00 -0.34 -0.01  0.15  0.012
# 1        19630702    0.79 -0.27  0.27 -0.07 -0.19  0.012
# 2        19630703    0.63 -0.17 -0.10  0.17 -0.33  0.012
# 3        19630705    0.40  0.08 -0.27  0.08 -0.33  0.012
# 4        19630708   -0.63  0.04 -0.19 -0.29  0.13  0.012
# ...           ...     ...   ...   ...   ...   ...    ...
# 14595    20210624    0.68  0.70  0.23 -0.39  0.23  0.000
# 14596    20210625    0.32 -0.48  0.46 -0.15  0.06  0.000
# 14597    20210628    0.23 -0.83 -1.59 -0.45 -0.17  0.000
# 14598    20210629    0.01 -0.37 -0.27  0.32  0.42  0.000
# 14599    20210630    0.08  0.13  0.78  0.70  0.62  0.000
#
# [14600 rows x 7 columns]

# %%
ff_factors_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14600 entries, 0 to 14599
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14600 non-null  int64
#  1   Mkt-RF      14600 non-null  float64
#  2   SMB         14600 non-null  float64
#  3   HML         14600 non-null  float64
#  4   RMW         14600 non-null  float64
#  5   CMA         14600 non-null  float64
#  6   RF          14600 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 798.6 KB

# %%
ff_factors_original.rename(columns={'Unnamed: 0':'date'}, inplace=True)
ff_factors_original
# Out:
#            date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0      19630701   -0.67  0.00 -0.34 -0.01  0.15  0.012
# 1      19630702    0.79 -0.27  0.27 -0.07 -0.19  0.012
# 2      19630703    0.63 -0.17 -0.10  0.17 -0.33  0.012
# 3      19630705    0.40  0.08 -0.27  0.08 -0.33  0.012
# 4      19630708   -0.63  0.04 -0.19 -0.29  0.13  0.012
# ...         ...     ...   ...   ...   ...   ...    ...
# 14595  20210624    0.68  0.70  0.23 -0.39  0.23  0.000
# 14596  20210625    0.32 -0.48  0.46 -0.15  0.06  0.000
# 14597  20210628    0.23 -0.83 -1.59 -0.45 -0.17  0.000
# 14598  20210629    0.01 -0.37 -0.27  0.32  0.42  0.000
# 14599  20210630    0.08  0.13  0.78  0.70  0.62  0.000
#
# [14600 rows x 7 columns]

# %%
ff_factors_original['date']=pd.to_datetime(ff_factors_original['date'], format='%Y%m%d')
ff_factors_original.set_index('date', inplace=True)
ff_factors_original
# Out:
#             Mkt-RF   SMB   HML   RMW   CMA     RF
# date
# 1963-07-01   -0.67  0.00 -0.34 -0.01  0.15  0.012
# 1963-07-02    0.79 -0.27  0.27 -0.07 -0.19  0.012
# 1963-07-03    0.63 -0.17 -0.10  0.17 -0.33  0.012
# 1963-07-05    0.40  0.08 -0.27  0.08 -0.33  0.012
# 1963-07-08   -0.63  0.04 -0.19 -0.29  0.13  0.012
# ...            ...   ...   ...   ...   ...    ...
# 2021-06-24    0.68  0.70  0.23 -0.39  0.23  0.000
# 2021-06-25    0.32 -0.48  0.46 -0.15  0.06  0.000
# 2021-06-28    0.23 -0.83 -1.59 -0.45 -0.17  0.000
# 2021-06-29    0.01 -0.37 -0.27  0.32  0.42  0.000
# 2021-06-30    0.08  0.13  0.78  0.70  0.62  0.000
#
# [14600 rows x 6 columns]

# %%
ff_factors_original=ff_factors_original.div(100) #transform percentages to real numbers
ff_factors_original
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA       RF
# date
# 1963-07-01 -0.0067  0.0000 -0.0034 -0.0001  0.0015  0.00012
# 1963-07-02  0.0079 -0.0027  0.0027 -0.0007 -0.0019  0.00012
# 1963-07-03  0.0063 -0.0017 -0.0010  0.0017 -0.0033  0.00012
# 1963-07-05  0.0040  0.0008 -0.0027  0.0008 -0.0033  0.00012
# 1963-07-08 -0.0063  0.0004 -0.0019 -0.0029  0.0013  0.00012
# ...            ...     ...     ...     ...     ...      ...
# 2021-06-24  0.0068  0.0070  0.0023 -0.0039  0.0023  0.00000
# 2021-06-25  0.0032 -0.0048  0.0046 -0.0015  0.0006  0.00000
# 2021-06-28  0.0023 -0.0083 -0.0159 -0.0045 -0.0017  0.00000
# 2021-06-29  0.0001 -0.0037 -0.0027  0.0032  0.0042  0.00000
# 2021-06-30  0.0008  0.0013  0.0078  0.0070  0.0062  0.00000
#
# [14600 rows x 6 columns]

# %%
rf=ff_factors_original['RF'].to_frame()
rf
# Out:
#                  RF
# date
# 1963-07-01  0.00012
# 1963-07-02  0.00012
# 1963-07-03  0.00012
# 1963-07-05  0.00012
# 1963-07-08  0.00012
# ...             ...
# 2021-06-24  0.00000
# 2021-06-25  0.00000
# 2021-06-28  0.00000
# 2021-06-29  0.00000
# 2021-06-30  0.00000
#
# [14600 rows x 1 columns]

# %%
ff_factors_original.drop(columns='RF', inplace=True)
ff_factors_original
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA
# date
# 1963-07-01 -0.0067  0.0000 -0.0034 -0.0001  0.0015
# 1963-07-02  0.0079 -0.0027  0.0027 -0.0007 -0.0019
# 1963-07-03  0.0063 -0.0017 -0.0010  0.0017 -0.0033
# 1963-07-05  0.0040  0.0008 -0.0027  0.0008 -0.0033
# 1963-07-08 -0.0063  0.0004 -0.0019 -0.0029  0.0013
# ...            ...     ...     ...     ...     ...
# 2021-06-24  0.0068  0.0070  0.0023 -0.0039  0.0023
# 2021-06-25  0.0032 -0.0048  0.0046 -0.0015  0.0006
# 2021-06-28  0.0023 -0.0083 -0.0159 -0.0045 -0.0017
# 2021-06-29  0.0001 -0.0037 -0.0027  0.0032  0.0042
# 2021-06-30  0.0008  0.0013  0.0078  0.0070  0.0062
#
# [14600 rows x 5 columns]

# %%
ff_factors_original.describe()
# Out:
#              Mkt-RF           SMB           HML           RMW           CMA
# count  14600.000000  14600.000000  14600.000000  14600.000000  14600.000000
# mean       0.000281      0.000081      0.000137      0.000127      0.000127
# std        0.010137      0.005378      0.005559      0.003796      0.003683
# min       -0.174400     -0.111700     -0.048900     -0.030200     -0.059400
# 25%       -0.004100     -0.002700     -0.002300     -0.001700     -0.001800
# 50%        0.000500      0.000200      0.000100      0.000100      0.000100
# 75%        0.005000      0.003000      0.002500      0.001900      0.001900
# max        0.113500      0.060800      0.067000      0.044900      0.025300

# %%
ff_factors_original.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ff_factors_original.add(1).cumprod().plot(figsize=(20,10)) #gross returns
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ff_factors_original['Mkt-RF'].plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ff_factors_original.resample('2M').mean()['Mkt-RF'].plot(kind='hist', bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ff_factors_original.resample('6M').mean()['Mkt-RF'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# ?ff_factors_original.plot

# %% [markdown]
# ## Stocks and crypto from Yahoo Finance

# %% [markdown]
# Direct download from URL csv. Right-click on "download" button on yahoo finance copy URL

# %%
# url = "https://query1.finance.yahoo.com/v7/finance/download/DOGE-USD?period1=1594886617&period2=1626422617&interval=1d&events=history&includeAdjustedClose=true"
# file=urllib.request.urlretrieve(url,'DOGE-USD.csv')
# pd.read_csv('DOGE-USD.csv', )

# %% [markdown]
# Download with API

# %% [markdown]
# https://pypi.org/project/yfinance/

# %%
# if os.path.exists(os.path.join(data_folder,'findata.csv')): 
#     os.remove(foldfilename)
#     print('data already downloaded')

# %% [markdown]
# Example

# %%
# data = yf.Ticker("DOGE-USD").history(start="2017-01-01", end="2017-04-30")
# data

# %%
stocktick=['DOGE-USD', 'GME']
stocktick
# Out:
# ['DOGE-USD', 'GME']

# %% [markdown]
# importat pagaes to understand how to work with dates
# https://www.programiz.com/python-programming/datetime/strftime<br>
# https://www.programiz.com/python-programming/datetime/strptime<br>
# especially for the data format code

# %%
event_dates={'DOGE-USD':pd.Timestamp('5-8-2021'), 'GME':pd.Timestamp('22-1-2021')}
event_dates
# Out:
# {'DOGE-USD': Timestamp('2021-05-08 00:00:00'),
#  'GME': Timestamp('2021-01-22 00:00:00')}

# %%
# dt.datetime.now() - pd.Timedelta('1Y 3W 3H 567M')

# %%
findata=pd.DataFrame()

#loop to download all stocks historical data
for ticker in tqdm(stocktick):
    stock = yf.Ticker(ticker)
    startdate=(event_dates[ticker] - pd.Timedelta('1Y')).strftime('%Y-%m-%d')
    enddate=(event_dates[ticker] + pd.Timedelta('4W')).strftime('%Y-%m-%d')
    print("downloading ticker {} from {} to {}".format(ticker, startdate, enddate))
    hist = stock.history(start=startdate, end=enddate)
    hist.loc[:,"ticker"]=ticker

    #concatenate history data of a given stock onto the financial datafram (findata)
    findata=pd.concat([findata,hist], axis=0)
findata
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# downloading ticker DOGE-USD from 2020-05-07 to 2021-06-05
# 100%|██████████| 2/2 [00:00<00:00,  2.92it/s]
# downloading ticker GME from 2020-01-22 to 2021-02-19
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2020-05-07   0.002518   0.002678   0.002479   0.002664  284491226          0
# 2020-05-08   0.002659   0.002672   0.002594   0.002625  291757355          0
# 2020-05-09   0.002622   0.002634   0.002565   0.002613  294993696          0
# 2020-05-10   0.002611   0.002613   0.002360   0.002459  290801097          0
# 2020-05-11   0.002457   0.002512   0.002338   0.002413  277646033          0
# ...               ...        ...        ...        ...        ...        ...
# 2021-02-11  50.009998  55.320000  48.220001  51.099998   13056700          0
# 2021-02-12  50.750000  55.240002  48.049999  52.400002   14573300          0
# 2021-02-16  52.660000  53.500000  49.040001  49.509998    8175000          0
# 2021-02-17  49.770000  51.189999  44.560001  45.939999    9186800          0
# 2021-02-18  48.490002  48.869999  40.650002  40.689999   23990600          0
#
#             Stock Splits    ticker
# Date
# 2020-05-07             0  DOGE-USD
# 2020-05-08             0  DOGE-USD
# 2020-05-09             0  DOGE-USD
# 2020-05-10             0  DOGE-USD
# 2020-05-11             0  DOGE-USD
# ...                  ...       ...
# 2021-02-11             0       GME
# 2021-02-12             0       GME
# 2021-02-16             0       GME
# 2021-02-17             0       GME
# 2021-02-18             0       GME
#
# [664 rows x 8 columns]

# %%
findata.set_index('ticker', append=True, inplace=True)
findata
# Out:
#                           Open       High        Low      Close     Volume  \
# Date       ticker
# 2020-05-07 DOGE-USD   0.002518   0.002678   0.002479   0.002664  284491226
# 2020-05-08 DOGE-USD   0.002659   0.002672   0.002594   0.002625  291757355
# 2020-05-09 DOGE-USD   0.002622   0.002634   0.002565   0.002613  294993696
# 2020-05-10 DOGE-USD   0.002611   0.002613   0.002360   0.002459  290801097
# 2020-05-11 DOGE-USD   0.002457   0.002512   0.002338   0.002413  277646033
# ...                        ...        ...        ...        ...        ...
# 2021-02-11 GME       50.009998  55.320000  48.220001  51.099998   13056700
# 2021-02-12 GME       50.750000  55.240002  48.049999  52.400002   14573300
# 2021-02-16 GME       52.660000  53.500000  49.040001  49.509998    8175000
# 2021-02-17 GME       49.770000  51.189999  44.560001  45.939999    9186800
# 2021-02-18 GME       48.490002  48.869999  40.650002  40.689999   23990600
#
#                      Dividends  Stock Splits
# Date       ticker
# 2020-05-07 DOGE-USD          0             0
# 2020-05-08 DOGE-USD          0             0
# 2020-05-09 DOGE-USD          0             0
# 2020-05-10 DOGE-USD          0             0
# 2020-05-11 DOGE-USD          0             0
# ...                        ...           ...
# 2021-02-11 GME               0             0
# 2021-02-12 GME               0             0
# 2021-02-16 GME               0             0
# 2021-02-17 GME               0             0
# 2021-02-18 GME               0             0
#
# [664 rows x 7 columns]

# %% [markdown]
# # Data preparation

# %%
returns=findata.groupby('ticker')['Close'].pct_change(1).to_frame().rename(columns={'Close':'ret'})
returns
# Out:
#                           ret
# Date       ticker
# 2020-05-07 DOGE-USD       NaN
# 2020-05-08 DOGE-USD -0.014640
# 2020-05-09 DOGE-USD -0.004571
# 2020-05-10 DOGE-USD -0.058936
# 2020-05-11 DOGE-USD -0.018707
# ...                       ...
# 2021-02-11 GME      -0.001953
# 2021-02-12 GME       0.025440
# 2021-02-16 GME      -0.055153
# 2021-02-17 GME      -0.072107
# 2021-02-18 GME      -0.114279
#
# [664 rows x 1 columns]

# %% [markdown]
# plot and describe the data

# %%
returns=findata['Close'].unstack('ticker').pct_change(1)
returns
# Out:
# ticker      DOGE-USD       GME
# Date
# 2020-01-22       NaN       NaN
# 2020-01-23       NaN  0.013158
# 2020-01-24       NaN -0.064935
# 2020-01-27       NaN -0.009259
# 2020-01-28       NaN -0.016355
# ...              ...       ...
# 2021-06-01  0.135868  0.000000
# 2021-06-02  0.144016  0.000000
# 2021-06-03 -0.055296  0.000000
# 2021-06-04 -0.059105  0.000000
# 2021-06-05 -0.011017  0.000000
#
# [469 rows x 2 columns]

# %%
findata.to_csv(os.path.join(data_folder,'findata.csv'))

# %% [markdown]
# # Data description

# %%
DOGE=returns['DOGE-USD'].dropna()
GME=returns['GME'].dropna()

# %%
DOGE.describe()
# Out:
# count    394.000000
# mean       0.021895
# std        0.181455
# min       -0.402570
# 25%       -0.023725
# 50%        0.000000
# 75%        0.019812
# max        2.756432
# Name: DOGE-USD, dtype: float64

# %%
DOGE.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
DOGE.resample('M').mean().plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
DOGE.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
GME.describe()
# Out:
# count    468.000000
# mean       0.010132
# std        0.114703
# min       -0.600000
# 25%       -0.009672
# 50%        0.000000
# 75%        0.013193
# max        1.348358
# Name: GME, dtype: float64

# %%
GME.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
GME.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
GME.resample('M').mean().plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Empirical tests

# %% [markdown]
# ## Weak-form EMH

# %% [markdown]
# ### Test 1 - returns follow a white noise

# %% [markdown]
# **Part1 Identical Distribution test- H0 returns are normally distributed - Shapiro-Wilk test**

# %% [markdown]
# Shapiro-Wilk test for normality<br>
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html<br>
#
# Alternatives:<br>
# Kolmogor-Smirnov<br>
# https://www.statsmodels.org/stable/generated/statsmodels.stats.diagnostic.kstest_normal.html

# %%
scipy.stats.shapiro(returns['DOGE-USD'].dropna())
# Out:
# ShapiroResult(statistic=0.4034919738769531, pvalue=5.451305460770433e-34)

# %% [markdown]
# H0 of normality rejected

# %%
scipy.stats.shapiro(returns['GME'].dropna())
# Out:
# ShapiroResult(statistic=0.5049498081207275, pvalue=4.308489393723524e-34)

# %% [markdown]
# H0 of normality rejected

# %% [markdown]
# **Part2 Autocorrelation test- H0 returns are independently distributed - Ljung-Box test**
# The data are independently distributed (i.e. the correlations in the population from which the sample is taken are 0, so that any observed correlations in the data result from randomness of the sampling process). Indedendency implies absence of correlation.

# %%
sm.stats.acorr_ljungbox(DOGE, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  10.28022   0.416262

# %% [markdown]
# H0 of independent returns cannot be rejected

# %%
sm.graphics.tsa.plot_acf(DOGE, lags=20)

# %%
sm.stats.acorr_ljungbox(GME, lags=[10], return_df=True)
# Out:
#       lb_stat     lb_pvalue
# 10  64.526915  4.991861e-10

# %% [markdown]
# H0 of independent returns cannot be rejected

# %%
sm.graphics.tsa.plot_acf(GME, lags=20)

# %% [markdown]
# H0 of independent returns cannot be rejected

# %% [markdown]
# ### Test 2 - test for Random Walk

# %% [markdown]
# Test whether the prices follow a random walk

# %%
DOGE_p=findata['Close'].unstack()['DOGE-USD'].dropna()
GME_p=findata['Close'].unstack()['GME'].dropna()

# %%
sm.graphics.tsa.plot_acf(DOGE_p, lags=20)

# %% [markdown]
# P0=10 because i cannot forecast the return (returns ~ white noise) then, the best forecast I can have for P1 is 10, I can forecast price because I cannot forecast returns
# P1=10 the best forecast for today is yeasterday price (Random walk)
# in conclusion past returns/prices are not useful to forecast (Weak-form efficiency cannot be rejected)

# %%
sm.graphics.tsa.plot_acf(GME_p, lags=20)

# %% [markdown]
# ## Semi-strong EMH

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Dates filtering

# %%
days_window=pd.Timedelta('20D')
days_window
# Out:
# Timedelta('20 days 00:00:00')

# %%
DOGE_ff5=pd.merge(pd.merge(DOGE,ff_factors_original, how='left', left_index=True, right_index=True), rf, how='left', left_index=True, right_index=True).ffill()
DOGE_ff5['DOGE-USD']=DOGE_ff5['DOGE-USD']-DOGE_ff5['RF']
DOGE_ff5=DOGE_ff5[DOGE_ff5.index<=event_dates['DOGE-USD'] + days_window]
DOGE_ff5
# Out:
#             DOGE-USD  Mkt-RF     SMB     HML     RMW     CMA   RF
# Date
# 2020-05-08 -0.014640  0.0190  0.0192  0.0248  0.0089  0.0039  0.0
# 2020-05-09 -0.004571  0.0190  0.0192  0.0248  0.0089  0.0039  0.0
# 2020-05-10 -0.058936  0.0190  0.0192  0.0248  0.0089  0.0039  0.0
# 2020-05-11 -0.018707  0.0007 -0.0023 -0.0375 -0.0082 -0.0006  0.0
# 2020-05-12  0.020721 -0.0206 -0.0115 -0.0135 -0.0068 -0.0006  0.0
# ...              ...     ...     ...     ...     ...     ...  ...
# 2021-05-24  0.188564  0.0100 -0.0048 -0.0069  0.0026 -0.0032  0.0
# 2021-05-25 -0.054238 -0.0030 -0.0083 -0.0122  0.0022 -0.0018  0.0
# 2021-05-26  0.021343  0.0047  0.0180  0.0052 -0.0046  0.0015  0.0
# 2021-05-27 -0.058661  0.0028  0.0108  0.0095 -0.0025  0.0025  0.0
# 2021-05-28 -0.065296  0.0004 -0.0037 -0.0027 -0.0022 -0.0041  0.0
#
# [386 rows x 7 columns]

# %%
DOGE_ff5.cumsum().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GME_ff5=pd.merge(pd.merge(GME,ff_factors_original, how='inner', left_index=True, right_index=True), rf, how='inner', left_index=True, right_index=True).ffill()
GME_ff5['GME']=GME_ff5['GME']-GME_ff5['RF']
GME_ff5=GME_ff5[GME_ff5.index<=event_dates['GME'] + days_window]
GME_ff5
# Out:
#                  GME  Mkt-RF     SMB     HML     RMW     CMA       RF
# 2020-01-23  0.013098  0.0008 -0.0007 -0.0014  0.0026 -0.0004  0.00006
# 2020-01-24 -0.064995 -0.0097 -0.0048 -0.0032  0.0017 -0.0004  0.00006
# 2020-01-27 -0.009319 -0.0156  0.0026 -0.0042 -0.0058  0.0005  0.00006
# 2020-01-28 -0.016415  0.0102 -0.0015 -0.0043  0.0015 -0.0010  0.00006
# 2020-01-29 -0.019062 -0.0010 -0.0045 -0.0096  0.0025  0.0019  0.00006
# 2020-01-30 -0.048486  0.0034 -0.0063  0.0063 -0.0038 -0.0012  0.00006
# 2020-01-31 -0.022961 -0.0174 -0.0053 -0.0034 -0.0058 -0.0069  0.00006
# 2020-02-03  0.028586  0.0084  0.0036 -0.0071 -0.0074 -0.0035  0.00006
# 2020-02-04  0.030320  0.0157 -0.0012 -0.0067  0.0034 -0.0015  0.00006
# 2020-02-05  0.026967  0.0097  0.0074  0.0148  0.0101  0.0065  0.00006
# 2020-02-06 -0.009629  0.0027 -0.0060 -0.0086 -0.0006 -0.0036  0.00006
# 2020-02-07 -0.079770 -0.0055 -0.0082  0.0000 -0.0019 -0.0052  0.00006
# 2020-02-10  0.034061  0.0073 -0.0018 -0.0090 -0.0012 -0.0041  0.00006
# 2020-02-11  0.020245  0.0028  0.0034  0.0107  0.0030  0.0023  0.00006
# 2020-02-12  0.042229  0.0066  0.0016 -0.0036  0.0022  0.0000  0.00006
# 2020-02-13 -0.019153 -0.0009  0.0013 -0.0002 -0.0015 -0.0041  0.00006
# 2020-02-14 -0.021958  0.0015 -0.0057 -0.0068 -0.0025 -0.0027  0.00006
# 2020-02-18  0.009890 -0.0019 -0.0002 -0.0068 -0.0049 -0.0067  0.00006
# 2020-02-19  0.022108  0.0060  0.0023 -0.0004  0.0011 -0.0033  0.00006
# 2020-02-20 -0.002470 -0.0035  0.0059  0.0067  0.0007 -0.0015  0.00006
# 2020-02-21 -0.024215 -0.0112 -0.0002  0.0002 -0.0017  0.0036  0.00006
# 2020-02-24 -0.084218 -0.0339  0.0015 -0.0001 -0.0036  0.0023  0.00006
# 2020-02-25 -0.037898 -0.0309 -0.0034 -0.0072 -0.0062  0.0002  0.00006
# 2020-02-26 -0.047813 -0.0052 -0.0078 -0.0121 -0.0051 -0.0011  0.00006
# 2020-02-27  0.023539 -0.0422  0.0070  0.0012 -0.0032 -0.0009  0.00006
# 2020-02-28  0.037404 -0.0078  0.0006 -0.0078  0.0030 -0.0040  0.00006
# 2020-03-02  0.063829  0.0431 -0.0195 -0.0040 -0.0055  0.0055  0.00006
# 2020-03-03 -0.052279 -0.0279  0.0064 -0.0062 -0.0048  0.0023  0.00006
# 2020-03-04  0.038507  0.0403 -0.0120 -0.0110  0.0011  0.0024  0.00006
# 2020-03-05  0.050338 -0.0338 -0.0018 -0.0137 -0.0090  0.0015  0.00006
# 2020-03-06 -0.010161 -0.0178 -0.0021 -0.0142  0.0076  0.0037  0.00006
# 2020-03-09 -0.056182 -0.0779 -0.0140 -0.0470  0.0009  0.0048  0.00006
# 2020-03-10  0.143183  0.0474 -0.0237  0.0078  0.0046  0.0006  0.00006
# 2020-03-11 -0.021337 -0.0505 -0.0105 -0.0079  0.0003  0.0010  0.00006
# 2020-03-12 -0.038707 -0.0963 -0.0114 -0.0121 -0.0037 -0.0026  0.00006
# 2020-03-13  0.153206  0.0896 -0.0202  0.0299  0.0119  0.0080  0.00006
# 2020-03-16 -0.047990 -0.1200 -0.0088 -0.0077  0.0059  0.0119  0.00006
# 2020-03-17 -0.032097  0.0587  0.0036 -0.0085 -0.0048 -0.0007  0.00006
# 2020-03-18 -0.108807 -0.0556 -0.0458 -0.0471  0.0027  0.0021  0.00006
# 2020-03-19  0.111346  0.0131  0.0573  0.0099 -0.0160 -0.0157  0.00006
# 2020-03-20 -0.102685 -0.0415  0.0030 -0.0090 -0.0074 -0.0120  0.00006
# 2020-03-23  0.013238 -0.0255  0.0165 -0.0350  0.0036 -0.0122  0.00006
# 2020-03-24  0.091803  0.0934 -0.0017  0.0235  0.0038  0.0022  0.00006
# 2020-03-25  0.002344  0.0118 -0.0015  0.0186 -0.0016  0.0013  0.00006
# 2020-03-26  0.057494  0.0602 -0.0045  0.0120 -0.0054  0.0004  0.00006
# 2020-03-27 -0.043144 -0.0348 -0.0105 -0.0069 -0.0108  0.0082  0.00006
# 2020-03-30 -0.135131  0.0316 -0.0080 -0.0216 -0.0020  0.0017  0.00006
# 2020-03-31 -0.041156 -0.0144  0.0151 -0.0042  0.0038 -0.0014  0.00006
# 2020-04-01 -0.071429 -0.0451 -0.0203 -0.0141  0.0016  0.0029  0.00000
# 2020-04-02 -0.123077  0.0210 -0.0093 -0.0028 -0.0008  0.0095  0.00000
# 2020-04-03 -0.017544 -0.0164 -0.0137 -0.0113 -0.0021  0.0040  0.00000
# 2020-04-06  0.103571  0.0706  0.0113  0.0027  0.0123 -0.0077  0.00000
# 2020-04-07  0.058252 -0.0011  0.0014  0.0216  0.0085 -0.0033  0.00000
# 2020-04-08  0.042813  0.0340  0.0088  0.0125  0.0041 -0.0021  0.00000
# 2020-04-09  0.140762  0.0159  0.0244  0.0319 -0.0092 -0.0009  0.00000
# 2020-04-13  0.218509 -0.0092 -0.0138 -0.0242 -0.0057 -0.0009  0.00000
# 2020-04-14  0.255274  0.0302 -0.0070 -0.0317  0.0019 -0.0036  0.00000
# 2020-04-15 -0.114286 -0.0215 -0.0194 -0.0250 -0.0038 -0.0033  0.00000
# 2020-04-16 -0.045541  0.0062 -0.0085 -0.0299 -0.0035 -0.0028  0.00000
# 2020-04-17 -0.029821  0.0272  0.0155  0.0271 -0.0017  0.0002  0.00000
# 2020-04-20  0.149590 -0.0156  0.0039 -0.0093 -0.0179 -0.0056  0.00000
# 2020-04-21 -0.147950 -0.0308  0.0097  0.0011  0.0024  0.0035  0.00000
# 2020-04-22  0.023012  0.0231 -0.0088 -0.0165  0.0017  0.0007  0.00000
# 2020-04-23 -0.038855  0.0013  0.0129  0.0054  0.0058 -0.0034  0.00000
# 2020-04-24  0.014894  0.0144  0.0029 -0.0012 -0.0017  0.0017  0.00000
# 2020-04-27  0.220126  0.0173  0.0219  0.0268 -0.0011  0.0020  0.00000
# 2020-04-28 -0.030928 -0.0045  0.0166  0.0282  0.0141  0.0073  0.00000
# 2020-04-29  0.070922  0.0292  0.0226  0.0200  0.0124 -0.0083  0.00000
# 2020-04-30 -0.051324 -0.0118 -0.0206 -0.0164  0.0069 -0.0009  0.00000
# 2020-05-01  0.055846 -0.0291 -0.0090 -0.0100 -0.0038  0.0036  0.00000
# 2020-05-04 -0.094215  0.0053 -0.0016 -0.0137 -0.0079 -0.0044  0.00000
# 2020-05-05 -0.016423  0.0095 -0.0026 -0.0198 -0.0055 -0.0051  0.00000
# 2020-05-06 -0.085343 -0.0052  0.0012 -0.0278  0.0012 -0.0064  0.00000
# 2020-05-07 -0.012170  0.0133  0.0016  0.0039 -0.0017 -0.0069  0.00000
# 2020-05-08  0.022587  0.0190  0.0192  0.0248  0.0089  0.0039  0.00000
# 2020-05-11 -0.044177  0.0007 -0.0023 -0.0375 -0.0082 -0.0006  0.00000
# 2020-05-12 -0.046219 -0.0206 -0.0115 -0.0135 -0.0068 -0.0006  0.00000
# 2020-05-13 -0.072687 -0.0189 -0.0146 -0.0212 -0.0007 -0.0026  0.00000
# 2020-05-14 -0.019002  0.0114 -0.0106  0.0093  0.0058  0.0010  0.00000
# 2020-05-15  0.021792  0.0057  0.0133 -0.0119 -0.0001 -0.0080  0.00000
# 2020-05-18  0.085308  0.0324  0.0263  0.0458  0.0170  0.0036  0.00000
# 2020-05-19 -0.030568 -0.0101 -0.0080 -0.0146  0.0048 -0.0068  0.00000
# 2020-05-20 -0.002252  0.0180  0.0121  0.0129 -0.0026 -0.0033  0.00000
# 2020-05-21  0.002257 -0.0070  0.0076  0.0041  0.0009  0.0000  0.00000
# 2020-05-22 -0.058559  0.0027  0.0025 -0.0087 -0.0058 -0.0038  0.00000
# 2020-05-26  0.057416  0.0123  0.0122  0.0459  0.0108  0.0062  0.00000
# 2020-05-27  0.061086  0.0154  0.0142  0.0362  0.0077  0.0040  0.00000
# 2020-05-28 -0.076759 -0.0041 -0.0201 -0.0241 -0.0017  0.0008  0.00000
# 2020-05-29 -0.062356  0.0060 -0.0079 -0.0197 -0.0032 -0.0046  0.00000
# 2020-06-01  0.017241  0.0052  0.0026  0.0045 -0.0004 -0.0024  0.00000
# 2020-06-02  0.012106  0.0081  0.0010  0.0045  0.0012  0.0023  0.00000
# 2020-06-03  0.062201  0.0142  0.0074  0.0266  0.0077  0.0024  0.00000
# 2020-06-04  0.006757 -0.0034  0.0050  0.0298  0.0101  0.0063  0.00000
# 2020-06-05 -0.073825  0.0250  0.0115  0.0267  0.0074  0.0006  0.00000
# 2020-06-08  0.210145  0.0139  0.0068  0.0215 -0.0045  0.0058  0.00000
# 2020-06-09 -0.009980 -0.0085 -0.0086 -0.0194 -0.0008 -0.0052  0.00000
# 2020-06-10  0.022177 -0.0056 -0.0179 -0.0416 -0.0035 -0.0035  0.00000
# 2020-06-11 -0.138067 -0.0591 -0.0150 -0.0306 -0.0030 -0.0026  0.00000
# 2020-06-12  0.080092  0.0129  0.0083  0.0186  0.0019  0.0002  0.00000
# 2020-06-15 -0.006356  0.0109  0.0140 -0.0041 -0.0075 -0.0027  0.00000
# 2020-06-16 -0.010661  0.0186  0.0064  0.0048  0.0070  0.0022  0.00000
# 2020-06-17  0.025862 -0.0040 -0.0135 -0.0198 -0.0054 -0.0027  0.00000
# 2020-06-18  0.039916  0.0019  0.0002 -0.0056 -0.0037 -0.0024  0.00000
# 2020-06-19 -0.014141 -0.0045 -0.0015 -0.0064 -0.0078 -0.0029  0.00000
# 2020-06-22 -0.002049  0.0071  0.0046 -0.0144 -0.0039 -0.0040  0.00000
# 2020-06-23 -0.008214  0.0042  0.0019 -0.0056  0.0056 -0.0011  0.00000
# 2020-06-24 -0.086957 -0.0261 -0.0074 -0.0130 -0.0009  0.0035  0.00000
# 2020-06-25  0.011338  0.0112  0.0035  0.0049 -0.0082  0.0014  0.00000
# 2020-06-26 -0.024664 -0.0244 -0.0015 -0.0142  0.0001  0.0070  0.00000
# 2020-06-29  0.006897  0.0151  0.0146  0.0177  0.0149  0.0038  0.00000
# 2020-06-30 -0.009132  0.0158 -0.0001  0.0000 -0.0039 -0.0027  0.00000
# 2020-07-01  0.023041  0.0041 -0.0168 -0.0251 -0.0043 -0.0122  0.00000
# 2020-07-02 -0.033784  0.0050  0.0001 -0.0009  0.0038  0.0018  0.00000
# 2020-07-06 -0.011655  0.0165 -0.0066  0.0037  0.0025 -0.0001  0.00000
# 2020-07-07 -0.035377 -0.0103 -0.0097 -0.0153 -0.0103 -0.0003  0.00000
# 2020-07-08  0.041565  0.0091  0.0009 -0.0046 -0.0043 -0.0033  0.00000
# 2020-07-09 -0.011737 -0.0053 -0.0154 -0.0259 -0.0031 -0.0059  0.00000
# 2020-07-10  0.030879  0.0111  0.0060  0.0303  0.0078  0.0018  0.00000
# 2020-07-13 -0.018433 -0.0120 -0.0029  0.0199  0.0114  0.0117  0.00000
# 2020-07-14 -0.042254  0.0135  0.0033 -0.0034 -0.0001  0.0045  0.00000
# 2020-07-15  0.026961  0.0114  0.0269  0.0128  0.0018  0.0010  0.00000
# 2020-07-16 -0.004773 -0.0037 -0.0016  0.0079  0.0031  0.0034  0.00000
# 2020-07-17 -0.050360  0.0030 -0.0015 -0.0141 -0.0106  0.0001  0.00000
# 2020-07-20 -0.027778  0.0101 -0.0109 -0.0238 -0.0085 -0.0131  0.00000
# 2020-07-21  0.041559  0.0016  0.0145  0.0323  0.0055  0.0091  0.00000
# 2020-07-22  0.024938  0.0049 -0.0061 -0.0034  0.0050  0.0002  0.00000
# 2020-07-23  0.000000 -0.0120  0.0122  0.0192 -0.0016  0.0019  0.00000
# 2020-07-24 -0.019465 -0.0075 -0.0078  0.0046  0.0029  0.0006  0.00000
# 2020-07-27 -0.004963  0.0088  0.0031 -0.0194 -0.0025  0.0007  0.00000
# 2020-07-28 -0.017456 -0.0081 -0.0044  0.0097  0.0028  0.0012  0.00000
# 2020-07-29  0.030457  0.0135  0.0065  0.0087  0.0023  0.0015  0.00000
# 2020-07-30  0.009852 -0.0029  0.0003 -0.0183 -0.0049 -0.0017  0.00000
# 2020-07-31 -0.021951  0.0061 -0.0177 -0.0065  0.0075  0.0072  0.00000
# 2020-08-03  0.034913  0.0098  0.0107 -0.0079 -0.0029  0.0030  0.00000
# 2020-08-04  0.067470  0.0037  0.0043  0.0005  0.0014  0.0006  0.00000
# 2020-08-05  0.045147  0.0078  0.0120  0.0085  0.0012 -0.0015  0.00000
# 2020-08-06 -0.043197  0.0053 -0.0060 -0.0079  0.0058  0.0007  0.00000
# 2020-08-07 -0.060948  0.0002  0.0152  0.0234  0.0049  0.0017  0.00000
# 2020-08-10  0.040865  0.0024  0.0127  0.0166  0.0086  0.0124  0.00000
# 2020-08-11  0.004619 -0.0083  0.0018  0.0157  0.0089  0.0007  0.00000
# 2020-08-12  0.039080  0.0140 -0.0081 -0.0130  0.0095 -0.0014  0.00000
# 2020-08-13  0.026549 -0.0001 -0.0012 -0.0130 -0.0063 -0.0055  0.00000
# 2020-08-14  0.023707 -0.0004  0.0004  0.0103  0.0040  0.0017  0.00000
# 2020-08-17 -0.025263  0.0045  0.0003 -0.0194 -0.0080 -0.0051  0.00000
# 2020-08-18  0.038877  0.0022 -0.0131 -0.0139  0.0004 -0.0055  0.00000
# 2020-08-19 -0.018711 -0.0038  0.0048  0.0008 -0.0002 -0.0011  0.00000
# 2020-08-20 -0.023305  0.0031 -0.0096 -0.0152  0.0004 -0.0050  0.00000
# 2020-08-21  0.091106  0.0025 -0.0120 -0.0042  0.0065  0.0073  0.00000
# 2020-08-24 -0.031809  0.0092  0.0023  0.0256  0.0107  0.0059  0.00000
# 2020-08-25  0.022587  0.0036 -0.0002 -0.0061 -0.0044 -0.0068  0.00000
# 2020-08-26  0.026104  0.0100 -0.0166 -0.0174 -0.0008 -0.0083  0.00000
# 2020-08-27  0.027397  0.0018 -0.0003  0.0098  0.0055 -0.0047  0.00000
# 2020-08-28  0.026667  0.0070  0.0040 -0.0022  0.0016 -0.0009  0.00000
# 2020-08-31  0.239332 -0.0004 -0.0093 -0.0175 -0.0064 -0.0015  0.00000
# 2020-09-01  0.145210  0.0092  0.0024 -0.0033  0.0058  0.0009  0.00000
# 2020-09-02  0.007843  0.0127 -0.0028 -0.0043  0.0071 -0.0036  0.00000
# 2020-09-03  0.014267 -0.0370  0.0042  0.0257 -0.0010 -0.0004  0.00000
# 2020-09-04 -0.021739 -0.0087  0.0033  0.0209  0.0080  0.0093  0.00000
# 2020-09-08  0.006536 -0.0291  0.0093 -0.0018 -0.0066 -0.0054  0.00000
# 2020-09-09 -0.045455  0.0207 -0.0058 -0.0196 -0.0010 -0.0023  0.00000
# 2020-09-10 -0.152381 -0.0164  0.0041 -0.0005 -0.0033 -0.0033  0.00000
# 2020-09-11 -0.022472 -0.0006 -0.0062  0.0091  0.0026  0.0048  0.00000
# 2020-09-14  0.134647  0.0159  0.0097 -0.0078 -0.0081 -0.0001  0.00000
# 2020-09-15  0.026049  0.0057 -0.0066 -0.0142  0.0008 -0.0040  0.00000
# 2020-09-16  0.224260 -0.0039  0.0115  0.0134 -0.0095  0.0023  0.00000
# 2020-09-17  0.059908 -0.0085  0.0048  0.0019  0.0010  0.0061  0.00000
# 2020-09-18  0.029348 -0.0088  0.0075 -0.0018 -0.0111 -0.0046  0.00000
# 2020-09-21 -0.076030 -0.0108 -0.0258 -0.0191 -0.0046 -0.0032  0.00000
# 2020-09-22  0.206857  0.0102 -0.0046 -0.0165  0.0060 -0.0055  0.00000
# 2020-09-23 -0.049242 -0.0248 -0.0063  0.0017  0.0026 -0.0012  0.00000
# 2020-09-24 -0.089641  0.0025 -0.0020  0.0032  0.0049  0.0011  0.00000
# 2020-09-25  0.096280  0.0172 -0.0016 -0.0135 -0.0050 -0.0070  0.00000
# 2020-09-28  0.006986  0.0166  0.0086  0.0102  0.0036  0.0019  0.00000
# 2020-09-29  0.025768 -0.0042  0.0042 -0.0130 -0.0078 -0.0059  0.00000
# 2020-09-30 -0.014493  0.0079 -0.0063  0.0018  0.0037  0.0015  0.00000
# 2020-10-01 -0.042157  0.0079  0.0081 -0.0057 -0.0003 -0.0061  0.00000
# 2020-10-02 -0.038895 -0.0096  0.0168  0.0244  0.0055  0.0035  0.00000
# 2020-10-05  0.007455  0.0193  0.0087 -0.0010 -0.0045  0.0010  0.00000
# 2020-10-06 -0.034884 -0.0128  0.0085  0.0024 -0.0053 -0.0006  0.00000
# 2020-10-07  0.025192  0.0184  0.0042  0.0024 -0.0029  0.0010  0.00000
# 2020-10-08  0.441239  0.0080  0.0026  0.0100  0.0019  0.0026  0.00000
# 2020-10-09 -0.108970  0.0093 -0.0032 -0.0142 -0.0015 -0.0032  0.00000
# 2020-10-12 -0.018303  0.0153 -0.0100 -0.0014  0.0074  0.0033  0.00000
# 2020-10-13  0.006780 -0.0041 -0.0017 -0.0169 -0.0084 -0.0095  0.00000
# 2020-10-14  0.031145 -0.0065  0.0002  0.0006  0.0035  0.0068  0.00000
# 2020-10-15  0.128980 -0.0008  0.0115  0.0112  0.0014  0.0017  0.00000
# 2020-10-16 -0.037599 -0.0006 -0.0015  0.0006 -0.0005 -0.0011  0.00000
# 2020-10-19  0.045079 -0.0153  0.0037  0.0028 -0.0032 -0.0025  0.00000
# 2020-10-20 -0.003595  0.0034 -0.0009  0.0128  0.0057  0.0023  0.00000
# 2020-10-21  0.017316 -0.0036 -0.0042  0.0030  0.0063  0.0008  0.00000
# 2020-10-22  0.057447  0.0067  0.0094  0.0107 -0.0051 -0.0003  0.00000
# 2020-10-23  0.006036  0.0038  0.0037  0.0005 -0.0020 -0.0039  0.00000
# 2020-10-26 -0.103333 -0.0185 -0.0045 -0.0039 -0.0004  0.0005  0.00000
# 2020-10-27 -0.056506 -0.0023 -0.0058 -0.0236 -0.0027 -0.0073  0.00000
# 2020-10-28 -0.068558 -0.0341  0.0022  0.0057 -0.0049  0.0001  0.00000
# 2020-10-29 -0.007614  0.0113  0.0014  0.0022  0.0023  0.0057  0.00000
# 2020-10-30 -0.107417 -0.0145 -0.0024  0.0185  0.0025  0.0000  0.00000
# 2020-11-02  0.026743  0.0117  0.0080  0.0098  0.0040  0.0036  0.00000
# 2020-11-03  0.076279  0.0193  0.0094 -0.0021 -0.0020  0.0000  0.00000
# 2020-11-04 -0.057044  0.0225 -0.0251 -0.0489 -0.0073 -0.0181  0.00000
# 2020-11-05  0.049496  0.0213  0.0104  0.0049  0.0024  0.0046  0.00000
# 2020-11-06  0.035808  0.0001 -0.0105 -0.0095 -0.0015 -0.0010  0.00000
# 2020-11-09 -0.031197  0.0087  0.0267  0.0670  0.0049  0.0090  0.00000
# 2020-11-10 -0.033943 -0.0017  0.0201  0.0217  0.0028  0.0133  0.00000
# 2020-11-11  0.058559  0.0088 -0.0106 -0.0175 -0.0057 -0.0020  0.00000
# 2020-11-12 -0.052766 -0.0094 -0.0056 -0.0118 -0.0064 -0.0024  0.00000
# 2020-11-13 -0.010782  0.0131  0.0089  0.0113  0.0054  0.0042  0.00000
# 2020-11-16  0.095368  0.0122  0.0121  0.0191  0.0064  0.0085  0.00000
# 2020-11-17 -0.035655 -0.0019  0.0060  0.0002 -0.0043 -0.0039  0.00000
# 2020-11-18 -0.005159 -0.0093 -0.0004  0.0000  0.0006 -0.0041  0.00000
# 2020-11-19  0.076923  0.0059  0.0030 -0.0072 -0.0062 -0.0024  0.00000
# 2020-11-20  0.020064 -0.0051  0.0062 -0.0061 -0.0071 -0.0011  0.00000
# 2020-11-23  0.093627  0.0083  0.0136  0.0155  0.0023  0.0000  0.00000
# 2020-11-24 -0.016547  0.0156  0.0046  0.0273  0.0044  0.0053  0.00000
# 2020-11-25  0.079005  0.0003 -0.0026 -0.0127 -0.0037 -0.0056  0.00000
# 2020-11-27  0.090169  0.0043  0.0013 -0.0164 -0.0079 -0.0037  0.00000
# 2020-11-30  0.029851 -0.0053 -0.0152 -0.0205 -0.0040  0.0046  0.00000
# 2020-12-01 -0.045894  0.0098 -0.0005  0.0054  0.0103  0.0050  0.00000
# 2020-12-02  0.049367  0.0011  0.0020  0.0105  0.0035  0.0058  0.00000
# 2020-12-03 -0.027744  0.0018  0.0051 -0.0005 -0.0030  0.0017  0.00000
# 2020-12-04  0.048387  0.0102  0.0153  0.0085 -0.0036  0.0057  0.00000
# 2020-12-07 -0.032544  0.0003 -0.0008 -0.0101 -0.0055 -0.0048  0.00000
# 2020-12-08  0.036086  0.0047  0.0084 -0.0075 -0.0070 -0.0004  0.00000
# 2020-12-09 -0.193625 -0.0103  0.0031  0.0134  0.0085  0.0039  0.00000
# 2020-12-10  0.033675  0.0024  0.0091 -0.0047 -0.0149 -0.0027  0.00000
# 2020-12-11 -0.057365 -0.0020 -0.0057 -0.0072 -0.0061 -0.0056  0.00000
# 2020-12-14 -0.044328 -0.0028  0.0023 -0.0154 -0.0041 -0.0085  0.00000
# 2020-12-15  0.088836  0.0128  0.0112  0.0040  0.0043  0.0057  0.00000
# 2020-12-16  0.000000  0.0017 -0.0057 -0.0037  0.0000 -0.0021  0.00000
# 2020-12-17  0.070758  0.0079  0.0051 -0.0067 -0.0062 -0.0018  0.00000
# 2020-12-18  0.053945 -0.0012 -0.0016 -0.0115 -0.0042 -0.0071  0.00000
# 2020-12-21 -0.006398 -0.0023  0.0024 -0.0003 -0.0096  0.0028  0.00000
# 2020-12-22  0.253059  0.0006  0.0087 -0.0162 -0.0086 -0.0014  0.00000
# 2020-12-23  0.057040  0.0010  0.0083  0.0200  0.0027  0.0043  0.00000
# 2020-12-24 -0.020418  0.0021 -0.0043 -0.0017  0.0024 -0.0005  0.00000
# 2020-12-28  0.041687  0.0046 -0.0065  0.0032  0.0146  0.0050  0.00000
# 2020-12-29 -0.076703 -0.0040 -0.0142  0.0024  0.0075 -0.0028  0.00000
# 2020-12-30 -0.006192  0.0027  0.0103  0.0004 -0.0067 -0.0006  0.00000
# 2020-12-31 -0.021807  0.0039 -0.0069  0.0045  0.0056 -0.0020  0.00000
# 2021-01-04 -0.084395 -0.0141  0.0019  0.0053 -0.0063  0.0006  0.00000
# 2021-01-05  0.006957  0.0086  0.0131  0.0051  0.0039  0.0056  0.00000
# 2021-01-06  0.056995  0.0079  0.0313  0.0389  0.0010  0.0060  0.00000
# 2021-01-07 -0.015251  0.0176  0.0001 -0.0085 -0.0148 -0.0026  0.00000
# 2021-01-08 -0.021571  0.0051 -0.0096 -0.0135 -0.0032 -0.0034  0.00000
# 2021-01-11  0.127190 -0.0051  0.0054  0.0124 -0.0016  0.0044  0.00000
# 2021-01-12  0.000502  0.0038  0.0143  0.0123 -0.0051  0.0038  0.00000
# 2021-01-13  0.573935  0.0007 -0.0103 -0.0042 -0.0021 -0.0006  0.00000
# 2021-01-14  0.271019 -0.0011  0.0233  0.0111 -0.0103  0.0037  0.00000
# 2021-01-15 -0.110499 -0.0086 -0.0071 -0.0074  0.0030 -0.0047  0.00000
# 2021-01-19  0.108732  0.0092  0.0072 -0.0084 -0.0070  0.0001  0.00000
# 2021-01-20 -0.006098  0.0126 -0.0076 -0.0112  0.0065 -0.0041  0.00000
# 2021-01-21  0.099949 -0.0004 -0.0076 -0.0094  0.0083  0.0034  0.00000
# 2021-01-22  0.510807 -0.0007  0.0161 -0.0016 -0.0062  0.0064  0.00000
# 2021-01-25  0.181203  0.0029 -0.0029 -0.0045  0.0030  0.0099  0.00000
# 2021-01-26  0.927074 -0.0032 -0.0002  0.0003  0.0100  0.0104  0.00000
# 2021-01-27  1.348358 -0.0253  0.0119  0.0147  0.0063  0.0243  0.00000
# 2021-01-28 -0.442894  0.0092 -0.0165 -0.0079 -0.0110 -0.0226  0.00000
# 2021-01-29  0.678719 -0.0184  0.0042  0.0056 -0.0063  0.0040  0.00000
# 2021-02-01 -0.307692  0.0173  0.0074 -0.0150 -0.0021 -0.0124  0.00000
# 2021-02-02 -0.600000  0.0148 -0.0077 -0.0107 -0.0101 -0.0214  0.00000
# 2021-02-03  0.026778  0.0015  0.0071  0.0087 -0.0020  0.0016  0.00000
# 2021-02-04 -0.421058  0.0123  0.0060  0.0033 -0.0015 -0.0026  0.00000
# 2021-02-05  0.191963  0.0058  0.0095 -0.0047 -0.0069  0.0040  0.00000
# 2021-02-08 -0.059119  0.0096  0.0219  0.0036 -0.0093  0.0071  0.00000
# 2021-02-09 -0.161500  0.0005  0.0068 -0.0018 -0.0069 -0.0045  0.00000
# 2021-02-10  0.017690 -0.0008 -0.0043  0.0067  0.0019  0.0000  0.00000
# 2021-02-11 -0.001953  0.0019 -0.0031 -0.0045 -0.0029 -0.0012  0.00000

# %%
GME_ff5.cumsum().plot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Prediction models - OLS Linear Regression

# %% [markdown]
# https://www.statsmodels.org/stable/regression.html

# %% [markdown]
# ### CAPM

# %%
DOGE_capm_model = sm.OLS(DOGE_ff5['DOGE-USD'], DOGE_ff5['Mkt-RF'])
DOGE_capm_results = DOGE_capm_model.fit()
print(DOGE_capm_results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               DOGE-USD   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.002
# Method:                 Least Squares   F-statistic:                             0.1580
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):                       0.691
# Time:                        15:43:43   Log-Likelihood:                          105.68
# No. Observations:                 386   AIC:                                     -209.4
# Df Residuals:                     385   BIC:                                     -205.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.3399      0.855      0.397      0.691      -1.342       2.022
# ==============================================================================
# Omnibus:                      654.155   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           288422.277
# Skew:                           9.658   Prob(JB):                         0.00
# Kurtosis:                     135.514   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
GME_capm_model = sm.OLS(GME_ff5['GME'], GME_ff5['Mkt-RF'])
GME_capm_results = GME_capm_model.fit()
print(GME_capm_results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    GME   R-squared (uncentered):                   0.007
# Model:                            OLS   Adj. R-squared (uncentered):              0.003
# Method:                 Least Squares   F-statistic:                              1.868
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):                       0.173
# Time:                        15:43:43   Log-Likelihood:                          125.04
# No. Observations:                 267   AIC:                                     -248.1
# Df Residuals:                     266   BIC:                                     -244.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5946      0.435      1.367      0.173      -0.262       1.451
# ==============================================================================
# Omnibus:                      261.529   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11286.674
# Skew:                           3.778   Prob(JB):                         0.00
# Kurtosis:                      33.943   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### FF5

# %%
X=DOGE_ff5.iloc[:,1:-1]
X=sm.add_constant(X)
DOGE_ff5_model = sm.OLS(DOGE_ff5['DOGE-USD'], X)
DOGE_ff5_results = DOGE_ff5_model.fit()
print(DOGE_ff5_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DOGE-USD   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4582
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):              0.807
# Time:                        15:43:43   Log-Likelihood:                 109.50
# No. Observations:                 386   AIC:                            -207.0
# Df Residuals:                     380   BIC:                            -183.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0226      0.010      2.364      0.019       0.004       0.041
# Mkt-RF         0.2868      0.948      0.302      0.762      -1.577       2.151
# SMB           -1.4776      1.518     -0.974      0.331      -4.462       1.506
# HML            1.2715      1.127      1.128      0.260      -0.944       3.487
# RMW           -3.3730      2.304     -1.464      0.144      -7.904       1.158
# CMA            0.5512      2.549      0.216      0.829      -4.461       5.563
# ==============================================================================
# Omnibus:                      647.746   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           274417.228
# Skew:                           9.477   Prob(JB):                         0.00
# Kurtosis:                     132.240   Cond. No.                         322.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X=GME_ff5.iloc[:,1:-1]
X=sm.add_constant(X)
GME_ff5_model = sm.OLS(GME_ff5['GME'], X)
GME_ff5_results = GME_ff5_model.fit()
print(GME_ff5_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GME   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     13.61
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):           8.19e-12
# Time:                        15:43:43   Log-Likelihood:                 157.05
# No. Observations:                 267   AIC:                            -302.1
# Df Residuals:                     261   BIC:                            -280.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0158      0.008      1.874      0.062      -0.001       0.032
# Mkt-RF         1.0143      0.419      2.420      0.016       0.189       1.840
# SMB            2.9985      1.018      2.946      0.004       0.994       5.003
# HML           -2.1586      0.830     -2.602      0.010      -3.792      -0.525
# RMW           -1.4708      1.692     -0.869      0.386      -4.803       1.861
# CMA           13.9781      1.889      7.401      0.000      10.259      17.697
# ==============================================================================
# Omnibus:                      210.888   Durbin-Watson:                   1.689
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4217.829
# Skew:                           2.965   Prob(JB):                         0.00
# Kurtosis:                      21.546   Cond. No.                         244.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## AR abnormal returns

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
DOGE_capm_AR=DOGE_ff5['DOGE-USD'] - DOGE_capm_results.predict()
DOGE_capm_AR.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
DOGE_ff5_model_AR=DOGE_ff5['DOGE-USD'] - DOGE_ff5_results.predict()
DOGE_ff5_model_AR.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GME_capm_AR=GME_ff5['GME'] - GME_capm_results.predict()
GME_capm_AR.plot()
# Out:
# <AxesSubplot:>

# %%
GME_ff5_model_AR=GME_ff5['GME'] - GME_ff5_results.predict()
GME_ff5_model_AR.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## CAR - Cumulative Abnormal Returns

# %% [markdown]
# **DOGE**

# %%
days_window_DOGE=pd.Timedelta('11D')
days_window_DOGE
# Out:
# Timedelta('11 days 00:00:00')

# %%
DOGE_capm_AR=DOGE_capm_AR[(DOGE_capm_AR.index >= event_dates['DOGE-USD'] - days_window_DOGE) & (DOGE_capm_AR.index < event_dates['DOGE-USD'] + days_window_DOGE)]

# %%
DOGE_capm_CAR=DOGE_capm_AR.cumsum()
DOGE_capm_CAR.index=list(range(-days_window_DOGE.days, days_window_DOGE.days))
matplotlib.pyplot.bar(DOGE_capm_CAR.index, DOGE_capm_CAR)
# Out:
# <BarContainer object of 22 artists>

# %%
DOGE_ff5_model_AR=DOGE_ff5_model_AR[(DOGE_ff5_model_AR.index >= event_dates['DOGE-USD'] - days_window_DOGE) & (DOGE_ff5_model_AR.index < event_dates['DOGE-USD'] + days_window_DOGE)]

# %%
DOGE_ff5_model_CAR=DOGE_ff5_model_AR.cumsum()
DOGE_ff5_model_CAR.index=list(range(-days_window_DOGE.days, days_window_DOGE.days))
matplotlib.pyplot.bar(DOGE_ff5_model_CAR.index, DOGE_ff5_model_CAR)
# Out:
# <BarContainer object of 22 artists>

# %% [markdown]
# **GME**

# %%
days_window_GME=pd.Timedelta('15D') #15D for -10 +10 windows
days_window_GME
# Out:
# Timedelta('15 days 00:00:00')

# %%
GME_capm_AR=GME_capm_AR[(GME_capm_AR.index >= event_dates['GME'] - days_window_GME) & (GME_capm_AR.index < event_dates['GME'] + days_window_GME)]
GME_capm_AR
# Out:
# 2021-01-07   -0.025716
# 2021-01-08   -0.024603
# 2021-01-11    0.130223
# 2021-01-12   -0.001758
# 2021-01-13    0.573519
# 2021-01-14    0.271673
# 2021-01-15   -0.105385
# 2021-01-19    0.103262
# 2021-01-20   -0.013590
# 2021-01-21    0.100187
# 2021-01-22    0.511223
# 2021-01-25    0.179479
# 2021-01-26    0.928976
# 2021-01-27    1.363401
# 2021-01-28   -0.448364
# 2021-01-29    0.689660
# 2021-02-01   -0.317979
# 2021-02-02   -0.608800
# 2021-02-03    0.025886
# 2021-02-04   -0.428372
# 2021-02-05    0.188514
# Name: GME, dtype: float64

# %%
GME_capm_CAR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-ad23a55dda67> in <module>
# ----> 1 GME_capm_CAR
#
# NameError: name 'GME_capm_CAR' is not defined

# %%
GME_capm_CAR=GME_capm_AR.cumsum()
GME_capm_CAR.index=list(range(-int((GME_capm_AR.shape[0]-1)/2), int((GME_capm_AR.shape[0]-1)/2)+1))
matplotlib.pyplot.bar(GME_capm_CAR.index, GME_capm_CAR)
# Out:
# <BarContainer object of 21 artists>

# %%
GME_ff5_model_AR=GME_ff5_model_AR[(GME_ff5_model_AR.index >= event_dates['GME'] - days_window_GME) & (GME_ff5_model_AR.index < event_dates['GME'] + days_window_GME)]
GME_ff5_model_AR
# Out:
# 2021-01-07   -0.052971
# 2021-01-08   -0.000076
# 2021-01-11    0.063287
# 2021-01-12   -0.096093
# 2021-01-13    0.584547
# 2021-01-14    0.143568
# 2021-01-15   -0.042145
# 2021-01-19    0.032191
# 2021-01-20    0.030810
# 2021-01-21    0.051740
# 2021-01-22    0.345413
# 2021-01-25    0.027478
# 2021-01-26    0.785109
# 2021-01-27    1.023874
# 2021-01-28   -0.135873
# 2021-01-29    0.615904
# 2021-02-01   -0.225364
# 2021-02-02   -0.346540
# 2021-02-03   -0.018354
# 2021-02-04   -0.426060
# 2021-02-05    0.065593
# Name: GME, dtype: float64

# %%
GME_ff5_model_CAR=GME_ff5_model_AR.cumsum()
GME_ff5_model_CAR.index=list(range(-int((GME_ff5_model_AR.shape[0]-1)/2), int((GME_ff5_model_AR.shape[0]-1)/2)+1))
matplotlib.pyplot.bar(GME_ff5_model_CAR.index, GME_ff5_model_CAR)
# Out:
# <BarContainer object of 21 artists>

# %% [markdown]
# ## BHAR - Buy and Hold Abnormal Returns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **DOGE**

# %%
DOGE_capm_BHAR=DOGE_capm_AR.add(1).cumprod()
DOGE_capm_BHAR.index=list(range(-days_window_DOGE.days, days_window_DOGE.days))
matplotlib.pyplot.bar(DOGE_capm_BHAR.index, DOGE_capm_BHAR)
# Out:
# <BarContainer object of 22 artists>

# %%
DOGE_ff5_model_BHAR=DOGE_ff5_model_AR.add(1).cumprod()
DOGE_ff5_model_BHAR.index=list(range(-days_window_DOGE.days, days_window_DOGE.days))
matplotlib.pyplot.bar(DOGE_ff5_model_BHAR.index, DOGE_ff5_model_BHAR)
# Out:
# <BarContainer object of 22 artists>

# %% [markdown]
# **GME**

# %%
GME_capm_BHAR=GME_capm_AR.add(1).cumprod()
GME_capm_BHAR.index=list(range(-int((GME_capm_AR.shape[0]-1)/2), int((GME_capm_AR.shape[0]-1)/2)+1))
matplotlib.pyplot.bar(GME_capm_BHAR.index, GME_capm_BHAR)
# Out:
# <BarContainer object of 21 artists>

# %%
GME_ff5_model_BHAR=GME_ff5_model_AR.add(1).cumprod()
GME_ff5_model_BHAR.index=list(range(-int((GME_ff5_model_AR.shape[0]-1)/2), int((GME_ff5_model_AR.shape[0]-1)/2)+1))
matplotlib.pyplot.bar(GME_ff5_model_BHAR.index, GME_ff5_model_BHAR)
# Out:
# <BarContainer object of 21 artists>

# %% [markdown]
# ## T-test: H0: the event has no impact on the asset prices (CAR or BHAR mean=0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # References

# %% [markdown]
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
# - https://www.eventstudytools.com/significance-tests#t-test
# - https://ebrary.net/732/business_finance/market_efficiency
